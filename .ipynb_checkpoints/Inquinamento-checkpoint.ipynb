# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import scipy.stats
from stldecompose import decompose, forecast
from stldecompose.forecast_funcs import (naive, drift, mean, seasonal_naive)
import seaborn as sns; sns.set()
from sklearn.preprocessing import Normalizer

data_pm10 = pd.read_csv('pm10.csv')
data_no2 = pd.read_csv('NO2.csv')
print(len(data_no2))
data_pm10.head(10)
# Out:
# 2927
#     Stazione Data inizio   Data fine    Strumento  PM10 Unità di misura  F1  \
# 0  DE AMICIS  31/12/2019  01/01/2020  FAI SWAM 5A  42.0           ug/m3 NaN
# 1  DE AMICIS  01/01/2020  02/01/2020  FAI SWAM 5A  39.0           ug/m3 NaN
# 2  DE AMICIS  02/01/2020  03/01/2020  FAI SWAM 5A  49.0           ug/m3 NaN
# 3  DE AMICIS  03/01/2020  04/01/2020  FAI SWAM 5A  44.0           ug/m3 NaN
# 4  DE AMICIS  04/01/2020  05/01/2020  FAI SWAM 5A  27.0           ug/m3 NaN
# 5  DE AMICIS  05/01/2020  06/01/2020  FAI SWAM 5A  28.0           ug/m3 NaN
# 6  DE AMICIS  06/01/2020  07/01/2020  FAI SWAM 5A  18.0           ug/m3 NaN
# 7  DE AMICIS  07/01/2020  08/01/2020  FAI SWAM 5A  53.0           ug/m3 NaN
# 8  DE AMICIS  08/01/2020  09/01/2020  FAI SWAM 5A  52.0           ug/m3 NaN
# 9  DE AMICIS  09/01/2020  10/01/2020  FAI SWAM 5A  45.0           ug/m3 NaN
#
#     F2  F3  F4
# 0  1.0   1   1
# 1  NaN   1   1
# 2  NaN   1   1
# 3  NaN   1   1
# 4  NaN   1   1
# 5  NaN   1   1
# 6  NaN   1   1
# 7  NaN   1   1
# 8  NaN   1   1
# 9  NaN   1   1

# %%
data_no2.head(10)
# Out:
#     Stazione          Data inizio           Data fine Strumento  \
# 0  DE AMICIS  31/12/2019 23.00.00          01/01/2020  API 200E
# 1  DE AMICIS           01/01/2020  01/01/2020 1.00.00  API 200E
# 2  DE AMICIS   01/01/2020 1.00.00  01/01/2020 2.00.00  API 200E
# 3  DE AMICIS   01/01/2020 2.00.00  01/01/2020 3.00.00  API 200E
# 4  DE AMICIS   01/01/2020 3.00.00  01/01/2020 4.00.00  API 200E
# 5  DE AMICIS   01/01/2020 4.00.00  01/01/2020 5.00.00  API 200E
# 6  DE AMICIS   01/01/2020 5.00.00  01/01/2020 6.00.00  API 200E
# 7  DE AMICIS   01/01/2020 6.00.00  01/01/2020 7.00.00  API 200E
# 8  DE AMICIS   01/01/2020 7.00.00  01/01/2020 8.00.00  API 200E
# 9  DE AMICIS   01/01/2020 8.00.00  01/01/2020 9.00.00  API 200E
#
#    NO2 (Biossido di azoto) Unità di misura  F1   F2   F3  F4
# 0                     16.0           ug/m3 NaN  1.0  1.0   1
# 1                     26.0           ug/m3 NaN  NaN  1.0   1
# 2                     25.0           ug/m3 NaN  NaN  1.0   1
# 3                     24.0           ug/m3 NaN  NaN  1.0   1
# 4                     32.0           ug/m3 NaN  NaN  1.0   1
# 5                     21.0           ug/m3 NaN  NaN  1.0   1
# 6                     18.0           ug/m3 NaN  NaN  1.0   1
# 7                     26.0           ug/m3 NaN  NaN  1.0   1
# 8                     29.0           ug/m3 NaN  NaN  1.0   1
# 9                     29.0           ug/m3 NaN  NaN  1.0   1

# %%
data_no2 = data_no2.iloc[::12, :]
data_no2 = data_no2.fillna(method='ffill')
len(data_no2)
# Out:
# 244

# %%
#data_pm10 = data_pm10.set_index('Data fine')
data_pm10 = data_pm10.fillna(method='ffill')
#data_no2 = data_no2.set_index('Data fine')

# %%
plt.figure(figsize = (18, 3))
plt.plot(data_pm10['PM10'], color = "red")
plt.axvline(x=60, color = "black")
plt.xlabel('Anno 2020 (Gennaio - Aprile)', fontsize=12)
plt.ylabel('Presenza PM10 µg/m³',  fontsize=12)
plt.xticks(rotation=60, fontsize=7)
plt.show()

# %%
plt.figure(figsize = (18, 3))
plt.plot(data_no2['NO2 (Biossido di azoto)'], color = "red")
plt.axvline(x=1500, color = "black")
plt.xlabel('Anno 2020 (Gennaio - Aprile)', fontsize=12)
plt.ylabel('Presenza NO2 µg/m³',  fontsize=12)
plt.xticks(rotation=60, fontsize=7)
plt.show()

# %% [markdown]
# ### Confronto dati tra traffico e inquinamento

# %%
zdata = pd.read_csv('zdata.csv')
zdata.head()
# Out:
#           Day       base2mid  Z.Totale
# 0  2020-01-01        Bologna  0.558516
# 1  2020-01-01        Ferrara  0.643222
# 2  2020-01-01  Forli'-Cesena  0.784004
# 3  2020-01-01         Modena  0.545689
# 4  2020-01-01          Parma  0.560193

# %%
agg_by_province = zdata.groupby(by = ['base2mid'])
for i, k in agg_by_province: 
    print(i, k)
# Out:
# Bologna             Day base2mid  Z.Totale
# 0    2020-01-01  Bologna  0.558516
# 9    2020-01-02  Bologna  0.812789
# 18   2020-01-03  Bologna  0.898452
# 27   2020-01-04  Bologna  0.834038
# 36   2020-01-05  Bologna  0.738255
# ..          ...      ...       ...
# 774  2020-03-27  Bologna  0.275517
# 783  2020-03-28  Bologna  0.130389
# 792  2020-03-29  Bologna  0.050407
# 801  2020-03-30  Bologna  0.290858
# 810  2020-03-31  Bologna  0.288367
#
# [91 rows x 3 columns]
# Ferrara             Day base2mid  Z.Totale
# 1    2020-01-01  Ferrara  0.643222
# 10   2020-01-02  Ferrara  0.883729
# 19   2020-01-03  Ferrara  0.919968
# 28   2020-01-04  Ferrara  0.871499
# 37   2020-01-05  Ferrara  0.812892
# ..          ...      ...       ...
# 775  2020-03-27  Ferrara  0.346398
# 784  2020-03-28  Ferrara  0.172844
# 793  2020-03-29  Ferrara  0.064501
# 802  2020-03-30  Ferrara  0.362325
# 811  2020-03-31  Ferrara  0.356896
#
# [91 rows x 3 columns]
# Forli'-Cesena             Day       base2mid  Z.Totale
# 2    2020-01-01  Forli'-Cesena  0.784004
# 11   2020-01-02  Forli'-Cesena  0.935211
# 20   2020-01-03  Forli'-Cesena  0.983486
# 29   2020-01-04  Forli'-Cesena  0.949108
# 38   2020-01-05  Forli'-Cesena  0.904885
# ..          ...            ...       ...
# 776  2020-03-27  Forli'-Cesena  0.265303
# 785  2020-03-28  Forli'-Cesena  0.129788
# 794  2020-03-29  Forli'-Cesena  0.049910
# 803  2020-03-30  Forli'-Cesena  0.283180
# 812  2020-03-31  Forli'-Cesena  0.281366
#
# [91 rows x 3 columns]
# Modena             Day base2mid  Z.Totale
# 3    2020-01-01   Modena  0.545689
# 12   2020-01-02   Modena  0.828035
# 21   2020-01-03   Modena  0.873385
# 30   2020-01-04   Modena  0.824551
# 39   2020-01-05   Modena  0.737053
# ..          ...      ...       ...
# 777  2020-03-27   Modena  0.239684
# 786  2020-03-28   Modena  0.110537
# 795  2020-03-29   Modena  0.046505
# 804  2020-03-30   Modena  0.257707
# 813  2020-03-31   Modena  0.252316
#
# [91 rows x 3 columns]
# Parma             Day base2mid  Z.Totale
# 4    2020-01-01    Parma  0.560193
# 13   2020-01-02    Parma  0.889647
# 22   2020-01-03    Parma  0.970251
# 31   2020-01-04    Parma  0.899300
# 40   2020-01-05    Parma  0.788805
# ..          ...      ...       ...
# 778  2020-03-27    Parma  0.303099
# 787  2020-03-28    Parma  0.142717
# 796  2020-03-29    Parma  0.046900
# 805  2020-03-30    Parma  0.315177
# 814  2020-03-31    Parma  0.311796
#
# [91 rows x 3 columns]
# Piacenza             Day  base2mid  Z.Totale
# 5    2020-01-01  Piacenza  0.540104
# 14   2020-01-02  Piacenza  0.837300
# 23   2020-01-03  Piacenza  0.903484
# 32   2020-01-04  Piacenza  0.863712
# 41   2020-01-05  Piacenza  0.800561
# ..          ...       ...       ...
# 779  2020-03-27  Piacenza  0.267701
# 788  2020-03-28  Piacenza  0.145363
# 797  2020-03-29  Piacenza  0.052587
# 806  2020-03-30  Piacenza  0.282220
# 815  2020-03-31  Piacenza  0.282814
#
# [91 rows x 3 columns]
# Ravenna             Day base2mid  Z.Totale
# 6    2020-01-01  Ravenna  0.706714
# 15   2020-01-02  Ravenna  0.889702
# 24   2020-01-03  Ravenna  0.956362
# 33   2020-01-04  Ravenna  0.904897
# 42   2020-01-05  Ravenna  0.834064
# ..          ...      ...       ...
# 780  2020-03-27  Ravenna  0.273709
# 789  2020-03-28  Ravenna  0.134858
# 798  2020-03-29  Ravenna  0.053659
# 807  2020-03-30  Ravenna  0.302525
# 816  2020-03-31  Ravenna  0.295548
#
# [91 rows x 3 columns]
# Reggio nell'Emilia             Day            base2mid  Z.Totale
# 7    2020-01-01  Reggio nell'Emilia  0.549153
# 16   2020-01-02  Reggio nell'Emilia  0.788009
# 25   2020-01-03  Reggio nell'Emilia  0.882067
# 34   2020-01-04  Reggio nell'Emilia  0.834402
# 43   2020-01-05  Reggio nell'Emilia  0.763208
# ..          ...                 ...       ...
# 781  2020-03-27  Reggio nell'Emilia  0.252656
# 790  2020-03-28  Reggio nell'Emilia  0.112623
# 799  2020-03-29  Reggio nell'Emilia  0.045169
# 808  2020-03-30  Reggio nell'Emilia  0.267292
# 817  2020-03-31  Reggio nell'Emilia  0.257940
#
# [91 rows x 3 columns]
# Rimini             Day base2mid  Z.Totale
# 8    2020-01-01   Rimini  0.742125
# 17   2020-01-02   Rimini  0.907048
# 26   2020-01-03   Rimini  0.962596
# 35   2020-01-04   Rimini  0.939076
# 44   2020-01-05   Rimini  0.863792
# ..          ...      ...       ...
# 782  2020-03-27   Rimini  0.210624
# 791  2020-03-28   Rimini  0.131201
# 800  2020-03-29   Rimini  0.051292
# 809  2020-03-30   Rimini  0.231248
# 818  2020-03-31   Rimini  0.229615
#
# [91 rows x 3 columns]

# %%
Piacenza = pd.read_csv('inquinamento/NO2/Piacenza.csv')
Bologna = pd.read_csv('inquinamento/NO2/Bologna.csv')
ReggioEmilia = pd.read_csv('inquinamento/NO2/ReggioEmilia.csv')
Modena = pd.read_csv('inquinamento/NO2/Modena.csv')
Parma = pd.read_csv('inquinamento/NO2/Parma.csv')
Rimini = pd.read_csv('inquinamento/NO2/Rimini.csv')
Forli = pd.read_csv('inquinamento/NO2/ForliCesena.csv')
Ravenna = pd.read_csv('inquinamento/NO2/ForliCesena.csv')
Ferrara = pd.read_csv('inquinamento/NO2/Ferrara.csv')
provincie = {'Bologna': Bologna, 
             'Ferrara': Ferrara, 
             'Forli\'-Cesena':Forli, 
             'Modena':Modena, 
             'Parma':Parma, 
             'Piacenza':Piacenza, 
             'Ravenna':Ravenna, 
             'Reggio nell\'Emilia':ReggioEmilia, 
             'Rimini':Rimini}

# %%
Ferrara.head(2)
# Out:
#        Stazione          Data inizio           Data fine Strumento  \
# 0  VILLA FULVIA  30/12/2019 23.00.00          31/12/2019  API 200E
# 1  VILLA FULVIA           31/12/2019  31/12/2019 1.00.00  API 200E
#
#    NO2 (Biossido di azoto) Unità di misura  F1   F2  F3  F4
# 0                     43.0           ug/m3 NaN  1.0   1   1
# 1                     39.0           ug/m3 NaN  1.0   1   1

# %%
corr_per_città_stazione = {}
for i, k in agg_by_province: 
    provincia_i = i
    df_provincia_i = provincie[provincia_i]
    agg_by_stz = df_provincia_i.groupby(by = ['Stazione'])
    for j, m in agg_by_stz:
        #m = m.drop(m.index[:24])
        m = m.fillna(method='bfill')
        m = m.rolling(24).mean()
        m = m.fillna(method='bfill')
        m = m.fillna(method='ffill')
        m = m.iloc[::24,:]
        #print(i, len(k))
        #print(j, len(m))
        if len(m)> len(k):
            diff = len(m)-len(k)
            m = m[diff:]
            #print('new m length ', len(m))
        if len(k) == len(m):
            città = k['Z.Totale'].values
            stazione = m['NO2 (Biossido di azoto)'].values
            mean_stazione = np.mean(stazione[:69])
            normal_stz = stazione / mean_stazione
            #norm_stz = np.linalg.norm(stazione)
            #normal_stz = stazione/norm_stz
            corr = scipy.stats.pearsonr(città, normal_stz)
            print(str(i)+" - "+str(j)+' ==> Pearson correlation, p-value '+str(corr))
            plt.figure(figsize = (6,4))
            plt.scatter(città, normal_stz)
            plt.xlabel('Traffico')
            plt.ylabel('NO2 (Biossido di azoto)')
            plt.show()
            
            città_stazione = i+"    ==>    "+i+"_"+j
            corr_per_città_stazione[città_stazione] = corr
           
        print('---------------')
# Out:
# Bologna - CASTELLUCCIO ==> Pearson correlation, p-value (0.2713307977124546, 0.009280405670061128)
# ---------------
# Bologna - DE AMICIS ==> Pearson correlation, p-value (0.5015161532571333, 4.107562022517198e-07)
# ---------------
# Bologna - GIARDINI MARGHERITA ==> Pearson correlation, p-value (0.5947194285364832, 5.104652159146729e-10)
# ---------------
# ---------------
# Bologna - SAN LAZZARO ==> Pearson correlation, p-value (0.5600955658472355, 7.808155126208884e-09)
# ---------------
# Bologna - SAN PIETRO CAPOFIUME ==> Pearson correlation, p-value (0.45913544984363025, 4.7035577167597425e-06)
# ---------------
# Bologna - VIA CHIARINI ==> Pearson correlation, p-value (0.6694916562129067, 4.010554102477212e-13)
# ---------------
# Ferrara - CENTO ==> Pearson correlation, p-value (0.5667395340296282, 4.739830928931438e-09)
# ---------------
# Ferrara - GHERARDI ==> Pearson correlation, p-value (0.424199877474194, 2.785367635806157e-05)
# ---------------
# Ferrara - ISONZO ==> Pearson correlation, p-value (0.6239036723472562, 3.930542300324794e-11)
# ---------------
# Ferrara - OSTELLATO ==> Pearson correlation, p-value (0.41503637847922126, 4.303253989399831e-05)
# ---------------
# Ferrara - VILLA FULVIA ==> Pearson correlation, p-value (0.5581160960718682, 9.041074680286377e-09)
# ---------------
# Forli'-Cesena - FRANCHINI-ANGELONI ==> Pearson correlation, p-value (0.730153758980522, 2.1775742168151942e-16)
# ---------------
# Forli'-Cesena - PARCO RESISTENZA ==> Pearson correlation, p-value (0.6601294414623413, 1.0969513526657386e-12)
# ---------------
# ---------------
# Forli'-Cesena - SAVIGNANO ==> Pearson correlation, p-value (0.6600682268038682, 1.1040624777233254e-12)
# ---------------
# Forli'-Cesena - SAVIGNANO DI RIGO ==> Pearson correlation, p-value (0.2882182952332596, 0.005597551911324353)
# ---------------
# Modena - GIARDINI ==> Pearson correlation, p-value (0.6579164154681136, 1.3842947010110359e-12)
# ---------------
# Modena - REMESINA ==> Pearson correlation, p-value (0.7191068554846589, 9.906951689474917e-16)
# ---------------
# Modena - SAN FRANCESCO ==> Pearson correlation, p-value (0.7235493207151709, 5.434453066736765e-16)
# ---------------
# Parma - BADIA ==> Pearson correlation, p-value (0.5406657874605135, 3.162044550842028e-08)
# ---------------
# Parma - CITTADELLA ==> Pearson correlation, p-value (0.6764461404861791, 1.8546603704107056e-13)
# ---------------
# Parma - MONTEBELLO ==> Pearson correlation, p-value (0.7155793755800517, 1.5829961061042637e-15)
# ---------------
# Parma - SARAGAT ==> Pearson correlation, p-value (0.7542657788292971, 6.066260894242977e-18)
# ---------------
# Piacenza - BESENZONE ==> Pearson correlation, p-value (0.6319434683346916, 1.8493176352386263e-11)
# ---------------
# ---------------
# Piacenza - GIORDANI-FARNESE ==> Pearson correlation, p-value (0.6204359044236402, 5.405182534413232e-11)
# ---------------
# Piacenza - LUGAGNANO ==> Pearson correlation, p-value (0.5890216846955607, 8.176039365620991e-10)
# ---------------
# Ravenna - FRANCHINI-ANGELONI ==> Pearson correlation, p-value (0.7140967122950599, 1.923614615932725e-15)
# ---------------
# Ravenna - PARCO RESISTENZA ==> Pearson correlation, p-value (0.6533895821169977, 2.2146755686475206e-12)
# ---------------
# ---------------
# Ravenna - SAVIGNANO ==> Pearson correlation, p-value (0.6398054442054122, 8.659650374054828e-12)
# ---------------
# Ravenna - SAVIGNANO DI RIGO ==> Pearson correlation, p-value (0.2653130889266796, 0.011032650339970841)
# ---------------
# Reggio nell'Emilia - CASTELLARANO ==> Pearson correlation, p-value (0.7506497461666152, 1.065046030998026e-17)
# ---------------
# Reggio nell'Emilia - S. LAZZARO ==> Pearson correlation, p-value (0.6806266079999566, 1.1548141390275245e-13)
# ---------------
# Reggio nell'Emilia - S. ROCCO ==> Pearson correlation, p-value (0.5869173648888576, 9.707320770591514e-10)
# ---------------
# Reggio nell'Emilia - TIMAVO ==> Pearson correlation, p-value (0.6428602562304166, 6.4106215583895975e-12)
# ---------------
# Rimini - FLAMINIA ==> Pearson correlation, p-value (0.6836613185606515, 8.147336321020942e-14)
# ---------------
# Rimini - MARECCHIA ==> Pearson correlation, p-value (0.5507558083788181, 1.5465429635701252e-08)
# ---------------
# ---------------
# Rimini - SAN LEO ==> Pearson correlation, p-value (0.055699596240070544, 0.599998624923005)
# ---------------
# Rimini - VERUCCHIO ==> Pearson correlation, p-value (0.5589623242288508, 8.492806000495706e-09)
# ---------------

# %%
corr_per_città_stazione
# Out:
# {'Bologna    ==>    Bologna_CASTELLUCCIO': (0.2713307977124546,
#   0.009280405670061128),
#  'Bologna    ==>    Bologna_DE AMICIS': (0.5015161532571333,
#   4.107562022517198e-07),
#  'Bologna    ==>    Bologna_GIARDINI MARGHERITA': (0.5947194285364832,
#   5.104652159146729e-10),
#  'Bologna    ==>    Bologna_SAN LAZZARO': (0.5600955658472355,
#   7.808155126208884e-09),
#  'Bologna    ==>    Bologna_SAN PIETRO CAPOFIUME': (0.45913544984363025,
#   4.7035577167597425e-06),
#  'Bologna    ==>    Bologna_VIA CHIARINI': (0.6694916562129067,
#   4.010554102477212e-13),
#  'Ferrara    ==>    Ferrara_CENTO': (0.5667395340296282,
#   4.739830928931438e-09),
#  'Ferrara    ==>    Ferrara_GHERARDI': (0.424199877474194,
#   2.785367635806157e-05),
#  'Ferrara    ==>    Ferrara_ISONZO': (0.6239036723472562,
#   3.930542300324794e-11),
#  'Ferrara    ==>    Ferrara_OSTELLATO': (0.41503637847922126,
#   4.303253989399831e-05),
#  'Ferrara    ==>    Ferrara_VILLA FULVIA': (0.5581160960718682,
#   9.041074680286377e-09),
#  "Forli'-Cesena    ==>    Forli'-Cesena_FRANCHINI-ANGELONI": (0.730153758980522,
#   2.1775742168151942e-16),
#  "Forli'-Cesena    ==>    Forli'-Cesena_PARCO RESISTENZA": (0.6601294414623413,
#   1.0969513526657386e-12),
#  "Forli'-Cesena    ==>    Forli'-Cesena_SAVIGNANO": (0.6600682268038682,
#   1.1040624777233254e-12),
#  "Forli'-Cesena    ==>    Forli'-Cesena_SAVIGNANO DI RIGO": (0.2882182952332596,
#   0.005597551911324353),
#  'Modena    ==>    Modena_GIARDINI': (0.6579164154681136,
#   1.3842947010110359e-12),
#  'Modena    ==>    Modena_REMESINA': (0.7191068554846589,
#   9.906951689474917e-16),
#  'Modena    ==>    Modena_SAN FRANCESCO': (0.7235493207151709,
#   5.434453066736765e-16),
#  'Parma    ==>    Parma_BADIA': (0.5406657874605135, 3.162044550842028e-08),
#  'Parma    ==>    Parma_CITTADELLA': (0.6764461404861791,
#   1.8546603704107056e-13),
#  'Parma    ==>    Parma_MONTEBELLO': (0.7155793755800517,
#   1.5829961061042637e-15),
#  'Parma    ==>    Parma_SARAGAT': (0.7542657788292971, 6.066260894242977e-18),
#  'Piacenza    ==>    Piacenza_BESENZONE': (0.6319434683346916,
#   1.8493176352386263e-11),
#  'Piacenza    ==>    Piacenza_GIORDANI-FARNESE': (0.6204359044236402,
#   5.405182534413232e-11),
#  'Piacenza    ==>    Piacenza_LUGAGNANO': (0.5890216846955607,
#   8.176039365620991e-10),
#  'Ravenna    ==>    Ravenna_FRANCHINI-ANGELONI': (0.7140967122950599,
#   1.923614615932725e-15),
#  'Ravenna    ==>    Ravenna_PARCO RESISTENZA': (0.6533895821169977,
#   2.2146755686475206e-12),
#  'Ravenna    ==>    Ravenna_SAVIGNANO': (0.6398054442054122,
#   8.659650374054828e-12),
#  'Ravenna    ==>    Ravenna_SAVIGNANO DI RIGO': (0.2653130889266796,
#   0.011032650339970841),
#  "Reggio nell'Emilia    ==>    Reggio nell'Emilia_CASTELLARANO": (0.7506497461666152,
#   1.065046030998026e-17),
#  "Reggio nell'Emilia    ==>    Reggio nell'Emilia_S. LAZZARO": (0.6806266079999566,
#   1.1548141390275245e-13),
#  "Reggio nell'Emilia    ==>    Reggio nell'Emilia_S. ROCCO": (0.5869173648888576,
#   9.707320770591514e-10),
#  "Reggio nell'Emilia    ==>    Reggio nell'Emilia_TIMAVO": (0.6428602562304166,
#   6.4106215583895975e-12),
#  'Rimini    ==>    Rimini_FLAMINIA': (0.6836613185606515,
#   8.147336321020942e-14),
#  'Rimini    ==>    Rimini_MARECCHIA': (0.5507558083788181,
#   1.5465429635701252e-08),
#  'Rimini    ==>    Rimini_SAN LEO': (0.055699596240070544, 0.599998624923005),
#  'Rimini    ==>    Rimini_VERUCCHIO': (0.5589623242288508,
#   8.492806000495706e-09)}

# %%
correlations = []
città_Stz = []

for k, v in corr_per_città_stazione.items(): 
    #print(type(k), type(v))
    correlations.append(v[0])
    città_Stz.append(k)

# %% [markdown]
# ### Histogramma delle correlazioni.

# %%
plt.hist(correlations, bins = 20)
plt.show()

# %% [markdown]
# ### Barplot correlazioni

# %%
plt.figure(figsize = (10,13))
plt.barh(città_Stz,correlations)
plt.yticks(città_Stz, size = 15)
plt.xlabel('Correlation', size = 15)
plt.show()

# %% [markdown]
# ### Correlazione per provincia

# %%
corr_per_prov= {}

prov_num = []
for i, k in agg_by_province: 
    provincia_i = i
    df_provincia_i = provincie[provincia_i]
    agg_by_stz = df_provincia_i.groupby(by = ['Stazione'])
    
    città = k['Z.Totale'].values
    
    for j, m in agg_by_stz:
        m = m.fillna(method='bfill')
        m = m.rolling(24).mean()
        m = m.fillna(method='bfill')
        m = m.fillna(method='ffill')
        m = m.iloc[::24,:]
        if len(k) != len(m): continue
        elif len(k) == len(m):
            li = m['NO2 (Biossido di azoto)'].tolist()
            prov_num = li
            
            prov_num = list( map(add, li, prov_num) )
         
    prov_num = np.array(prov_num)    
    mean_prov = np.mean(prov_num[:70])
    normal_stz = prov_num / mean_prov
    corr = scipy.stats.pearsonr(città, normal_stz)
    print( provincia_i, ' ==> Pearson correlation, p-value '+str(corr))
    corr_per_prov[provincia_i] = corr
    plt.figure(figsize = (8,6))
    plt.scatter(città, normal_stz)
    plt.xlabel('Traffico '+ str(provincia_i))
    plt.ylabel('NO2 (Biossido di azoto)')
    plt.show()
# Out:
# Bologna  ==> Pearson correlation, p-value (0.4591354498436303, 4.703557716759696e-06)
# Ferrara  ==> Pearson correlation, p-value (0.4496323345770161, 7.780975472185812e-06)
# Forli'-Cesena  ==> Pearson correlation, p-value (0.5409987488873398, 3.089445648811791e-08)
# Modena  ==> Pearson correlation, p-value (0.4767658370933102, 1.7746266143073934e-06)
# Parma  ==> Pearson correlation, p-value (0.5144152554827492, 1.8281512878912017e-07)
# Piacenza  ==> Pearson correlation, p-value (0.5890216846955607, 8.176039365620991e-10)
# Ravenna  ==> Pearson correlation, p-value (0.5861801092617285, 1.0306107025983228e-09)
# Reggio nell'Emilia  ==> Pearson correlation, p-value (0.5617303409086234, 6.912725399568621e-09)
# Rimini  ==> Pearson correlation, p-value (0.5507558083788181, 1.5465429635701252e-08)

# %%
corr_per_prov
# Out:
# {'Bologna': (0.4591354498436303, 4.703557716759696e-06),
#  'Ferrara': (0.4496323345770161, 7.780975472185812e-06),
#  "Forli'-Cesena": (0.5409987488873398, 3.089445648811791e-08),
#  'Modena': (0.4767658370933102, 1.7746266143073934e-06),
#  'Parma': (0.5144152554827492, 1.8281512878912017e-07),
#  'Piacenza': (0.5890216846955607, 8.176039365620991e-10),
#  'Ravenna': (0.5861801092617285, 1.0306107025983228e-09),
#  "Reggio nell'Emilia": (0.5617303409086234, 6.912725399568621e-09),
#  'Rimini': (0.5507558083788181, 1.5465429635701252e-08)}

# %%
correlations_prov = []
città_prov = []

for k, v in corr_per_prov.items(): 
    #print(type(k), type(v))
    correlations_prov.append(v[0])
    città_prov.append(k)
correlations_prov
# Out:
# [0.4591354498436303,
#  0.4496323345770161,
#  0.5409987488873398,
#  0.4767658370933102,
#  0.5144152554827492,
#  0.5890216846955607,
#  0.5861801092617285,
#  0.5617303409086234,
#  0.5507558083788181]

# %%
plt.figure(figsize = (8,10))
plt.barh(città_prov,correlations_prov)
plt.yticks(città_prov, size = 15)
plt.xlabel('Correlazione', size = 15)
# Out:
# Text(0.5, 0, 'Correlazione')
